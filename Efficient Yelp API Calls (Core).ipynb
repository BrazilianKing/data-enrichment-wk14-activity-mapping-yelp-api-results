# %% [markdown]
# # Efficient Yelp API Calls (Core)

# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Imports
import os, json, math, time
from tqdm.notebook import tqdm_notebook

# %%
# !pip install yelpapi
# Out:
# Collecting yelpapi
#   Downloading yelpapi-2.5.0-py3-none-any.whl (7.4 kB)
# Requirement already satisfied: requests in c:\users\badbr\anaconda3\envs\dojo-env\lib\site-packages (from yelpapi) (2.28.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\badbr\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\badbr\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\badbr\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\badbr\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (2.0.4)
# Installing collected packages: yelpapi
# Successfully installed yelpapi-2.5.0

# %%
from yelpapi import YelpAPI

# %% [markdown]
# ### Load Credentials and Create Yelp API Object

# %%
# Load API Credentials
with open ('C:/Users/badbr/.secret/yelp_api.json', 'r') as f:
    login = json.load(f)

# %%
# Instantiate YelpAPI Variable
Yelp = YelpAPI(login['api-key'], timeout_s = 5.0)

# %% [markdown]
# ### Define Search Terms and File Paths

# %%
# set our API call parameters and filename before the first call
location = 'Orlando, FL 34786'
term = 'steak'

# %%
location.split(',')[0]
# Out:
# 'Orlando'

# %%
## Specify fodler for saving data
FOLDER = 'Data/'

os.makedirs(FOLDER, exist_ok = True)

# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = FOLDER+f"{location.split(',')[0]}-{term}.json"

# %%
JSON_FILE
# Out:
# 'Data/Orlando-steak.json'

# %% [markdown]
# ### Check if Json File exists and Create it if it doesn't

# %%
## Check if JSON_FILE exists
file_exist = os.path.isfile(JSON_FILE)
## If it does not exist: 
if file_exist == False:  
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON_FILE included a folder:
    if len(folder)>0:
        # create the folder
        os.makedirs(folder, exist_ok = True)
        
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f'[i]{JSON_FILE} not found. Saving empty list to file.')
    
    
    ## save the first page of results
    with open (JSON_FILE, 'w') as f:
        json.dump([], f)
## If it exists, inform user
else:
    print(f'[i] {JSON_FILE} already exists.')
# Out:
# [i] Data/Orlando-steak.json already exists.

# %% [markdown]
# ### Make the first API call to get the first page of data

# %%
# use our yelp_api variable's search_query method to perform our API call
results = Yelp.search_query(term = term, location = location)

# %%
type(results)
# Out:
# dict

# %%
len(results)
# Out:
# 3

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['total']
# Out:
# 1900

# %%
results['region']
# Out:
# {'center': {'longitude': -81.55563354492188, 'latitude': 28.479517002460295}}

# %%
results['businesses']
# Out:
# [{'id': '9rIAl_UPCS3ODRMdSyaPgA',
#   'alias': 'steak-on-fire-orlando',
#   'name': 'Steak on Fire',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vzahwTxp5vh2LRwMNFwOQw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/steak-on-fire-orlando?adjust_creative=0sqSARBZBNeJkSSMstb4jg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0sqSARBZBNeJkSSMstb4jg',
#   'review_count': 358,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'brazilian', 'title': 'Brazilian'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 28.4506829, 'longitude': -81.485305},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '7541 Sand Lake Rd',
#    'address2': 'Ste A',
#    'address3': '',
#    'city': 'Orlando',
#    'zip_code': '32819',
#    'country': 'US',
#    'state': 'FL',
#    'display_address': ['7541 Sand Lake Rd', 'Ste A', 'Orlando, FL 32819']},
#   'phone': '+14074402323',
#   'display_phone': '(407) 440-2323',
#   'distance': 7585.656804304097},
#  {'id': 'yS73rFfQFV2ggXQSlhv3Uw',
#   'alias': 'matthews-steakhouse-winter-garden-2',
#   'name': "Matthew's Steakhouse",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jkRiGGN-SQeChnt6vQJXMA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/matthews-steakhouse-winter-garden-2?adjust_creative=0sqSARBZBNeJkSSMstb4jg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0sqSARBZBNeJkSSMstb4jg',
#   'review_count': 133,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 28.5645698339131,
#    'longitude': -81.5902531415437},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '360 W Plant St',
#    'address2': '',
#    'address3': None,
#    'city': 'Winter Garden',
#    'zip_code': '34787',
#    'country': 'US',
#    'state': 'FL',
#    'display_address': ['360 W Plant St', 'Winter Garden, FL 34787']},
#   'phone': '+14075207511',
#   'display_phone': '(407) 520-7511',
#   'distance': 10044.057790441526},
#  {'id': 'wit_AlzCJqyq8IIytFxORg',
#   'alias': 'the-wharf-at-sunset-walk-kissimmee-2',
#   'name': 'The Wharf at Sunset Walk',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6i1p7ctf1inYsQmIqEgP2g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-wharf-at-sunset-walk-kissimmee-2?adjust_creative=0sqSARBZBNeJkSSMstb4jg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0sqSARBZBNeJkSSMstb4jg',
#   'review_count': 418,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'modern_european', 'title': 'Modern European'},
#    {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 28.343873101245265,
#    'longitude': -81.6087531303005},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '3274 Margaritaville Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Kissimmee',
#    'zip_code': '34747',
#    'country': 'US',
#    'state': 'FL',
#    'display_address': ['3274 Margaritaville Blvd', 'Kissimmee, FL 34747']},
#   'phone': '+14079547290',
#   'display_phone': '(407) 954-7290',
#   'distance': 15769.757231715219},
#  {'id': 'uV0N049zQmA_PUnbIK3oyg',
#   'alias': 'eddie-vs-prime-seafood-orlando-2',
#   'name': "Eddie V's Prime Seafood",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8F2qYHPV1llFpuEG4d9UXw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/eddie-vs-prime-seafood-orlando-2?adjust_creative=0sqSARBZBNeJkSSMstb4jg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0sqSARBZBNeJkSSMstb4jg',
#   'review_count': 1048,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'lounges', 'title': 'Lounges'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 28.44976, 'longitude': -81.48521},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '7488 W Sand Lake Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Orlando',
#    'zip_code': '32819',
#    'country': 'US',
#    'state': 'FL',
#    'display_address': ['7488 W Sand Lake Rd', 'Orlando, FL 32819']},
#   'phone': '+14073553011',
#   'display_phone': '(407) 355-3011',
#   'distance': 7794.688479661379},
#  {'id': 'aBdD__fQY23MKOIPmekrXw',
#   'alias': 'the-whiskey-orlando',
#   'name': 'The Whiskey',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gCMLA89nmhE2NmfCs_QR4A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-whiskey-orlando?adjust_creative=0sqSARBZBNeJkSSMstb4jg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0sqSARBZBNeJkSSMstb4jg',
#   'review_count': 849,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'whiskeybars', 'title': 'Whiskey Bars'},
#    {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 28.450702, 'longitude': -81.486127},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '7563 W Sand Lake Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Orlando',
#    'zip_code': '32819',
#    'country': 'US',
#    'state': 'FL',
#    'display_address': ['7563 W Sand Lake Rd', 'Orlando, FL 32819']},
#   'phone': '+14079306517',
#   'display_phone': '(407) 930-6517',
#   'distance': 7512.004787592443},
#  {'id': '_N8r_L8osRlusLJLfF3MPA',
#   'alias': 'br77-brazilian-steakhouse-celebration',
#   'name': 'BR77 Brazilian Steakhouse',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rLcGIOCff6556zqEVpkZXw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/br77-brazilian-steakhouse-celebration?adjust_creative=0sqSARBZBNeJkSSMstb4jg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0sqSARBZBNeJkSSMstb4jg',
#   'review_count': 48,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'},
#    {'alias': 'brazilian', 'title': 'Brazilian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 28.344453143028165,
#    'longitude': -81.60904880864524},
#   'transactions': [],
#   'location': {'address1': '3228 Margaritaville Blvd',
#    'address2': None,
#    'address3': '',
#    'city': 'Celebration',
#    'zip_code': '34747',
#    'country': 'US',
#    'state': 'FL',
#    'display_address': ['3228 Margaritaville Blvd', 'Celebration, FL 34747']},
#   'phone': '+13219004377',
#   'display_phone': '(321) 900-4377',
#   'distance': 15901.04775597216},
#  {'id': 's2fM5fhc_QMow26UWugMog',
#   'alias': 'bull-and-bear-orlando-2',
#   'name': 'Bull and Bear',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WKgtcVh4Mnsl6MmvSHL0FQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bull-and-bear-orlando-2?adjust_creative=0sqSARBZBNeJkSSMstb4jg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0sqSARBZBNeJkSSMstb4jg',
#   'review_count': 446,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 28.352868, 'longitude': -81.533747},
#   'transactions': [],
#   'price': '$$$$',
#   'location': {'address1': '14200 Bonnet Creek Resort Ln',
#    'address2': '',
#    'address3': '',
#    'city': 'Orlando',
#    'zip_code': '32821',
#    'country': 'US',
#    'state': 'FL',
#    'display_address': ['14200 Bonnet Creek Resort Ln', 'Orlando, FL 32821']},
#   'phone': '+14075975500',
#   'display_phone': '(407) 597-5500',
#   'distance': 14244.446547485297},
#  {'id': 'ZmC6t-RbvQ_HaNuZ3kighA',
#   'alias': 'delmonicos-italian-steak-house-orlando',
#   'name': "Delmonico's Italian Steak House",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-EKhF9aq_c-4NhywX0ufXA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/delmonicos-italian-steak-house-orlando?adjust_creative=0sqSARBZBNeJkSSMstb4jg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0sqSARBZBNeJkSSMstb4jg',
#   'review_count': 1239,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 28.420272, 'longitude': -81.460726},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '6115 Westwood Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Orlando',
#    'zip_code': '32821',
#    'country': 'US',
#    'state': 'FL',
#    'display_address': ['6115 Westwood Blvd', 'Orlando, FL 32821']},
#   'phone': '+14072262662',
#   'display_phone': '(407) 226-2662',
#   'distance': 11379.523522957636},
#  {'id': 'fwrYgOJCja_a6GozuPmOew',
#   'alias': 'boteco-do-manolo-windermere',
#   'name': 'Boteco do Manolo',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Zg6yQv_vqfnGW-6LjmmOZA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/boteco-do-manolo-windermere?adjust_creative=0sqSARBZBNeJkSSMstb4jg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0sqSARBZBNeJkSSMstb4jg',
#   'review_count': 5,
#   'categories': [{'alias': 'brazilian', 'title': 'Brazilian'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 28.44898180468064,
#    'longitude': -81.56223567068466},
#   'transactions': [],
#   'location': {'address1': '11620 Lakeside Village Ln',
#    'address2': 'Ste 100',
#    'address3': None,
#    'city': 'Windermere',
#    'zip_code': '34786',
#    'country': 'US',
#    'state': 'FL',
#    'display_address': ['11620 Lakeside Village Ln',
#     'Ste 100',
#     'Windermere, FL 34786']},
#   'phone': '+14076148310',
#   'display_phone': '(407) 614-8310',
#   'distance': 3456.146665561025},
#  {'id': 'Vlwa2HgckFlUmAqTN1HEfQ',
#   'alias': 'teak-neighborhood-grill-orlando',
#   'name': 'Teak Neighborhood Grill',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HRjCIwqzTqzzBEI5_2YnGQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/teak-neighborhood-grill-orlando?adjust_creative=0sqSARBZBNeJkSSMstb4jg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0sqSARBZBNeJkSSMstb4jg',
#   'review_count': 969,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 28.50895, 'longitude': -81.47101},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '6400 Times Sq Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Orlando',
#    'zip_code': '32835',
#    'country': 'US',
#    'state': 'FL',
#    'display_address': ['6400 Times Sq Ave', 'Orlando, FL 32835']},
#   'phone': '+14073135111',
#   'display_phone': '(407) 313-5111',
#   'distance': 8921.531235961922},
#  {'id': '3E67cNRXVCfWu07GUzNqAg',
#   'alias': 'ocean-prime-orlando',
#   'name': 'Ocean Prime',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xxrdKNI7w3P7foEJn4kwxQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ocean-prime-orlando?adjust_creative=0sqSARBZBNeJkSSMstb4jg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0sqSARBZBNeJkSSMstb4jg',
#   'review_count': 676,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 28.45077631932273,
#    'longitude': -81.48032871651554},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '7339 W Sand Lake Rd 400',
#    'address2': 'Ste 400',
#    'address3': '',
#    'city': 'Orlando',
#    'zip_code': '32819',
#    'country': 'US',
#    'state': 'FL',
#    'display_address': ['7339 W Sand Lake Rd 400',
#     'Ste 400',
#     'Orlando, FL 32819']},
#   'phone': '+14077814880',
#   'display_phone': '(407) 781-4880',
#   'distance': 8025.000110764166},
#  {'id': 'yo0SkNe0fEAPObuRdAK4yg',
#   'alias': 'la-boucherie-orlando',
#   'name': 'La Boucherie',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6cR95X22XcV3oFG94n6WfQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/la-boucherie-orlando?adjust_creative=0sqSARBZBNeJkSSMstb4jg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0sqSARBZBNeJkSSMstb4jg',
#   'review_count': 408,
#   'categories': [{'alias': 'french', 'title': 'French'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 28.454501838355, 'longitude': -81.4774964831005},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '7625 Turkey Lake Rd',
#    'address2': None,
#    'address3': '',
#    'city': 'Orlando',
#    'zip_code': '32819',
#    'country': 'US',
#    'state': 'FL',
#    'display_address': ['7625 Turkey Lake Rd', 'Orlando, FL 32819']},
#   'phone': '+14079301708',
#   'display_phone': '(407) 930-1708',
#   'distance': 8334.427606053778},
#  {'id': 'P54EpC04TcfKcr-bYF12lA',
#   'alias': 'black-rock-bar-and-grill-orlando',
#   'name': 'Black Rock Bar & Grill',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/t1YuW-uvqJ7F9Uy73FuIRw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/black-rock-bar-and-grill-orlando?adjust_creative=0sqSARBZBNeJkSSMstb4jg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0sqSARBZBNeJkSSMstb4jg',
#   'review_count': 473,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 28.494411, 'longitude': -81.507644},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '8965 Conroy Windermere Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Orlando',
#    'zip_code': '32819',
#    'country': 'US',
#    'state': 'FL',
#    'display_address': ['8965 Conroy Windermere Rd', 'Orlando, FL 32819']},
#   'phone': '+14075055195',
#   'display_phone': '(407) 505-5195',
#   'distance': 4973.925874986016},
#  {'id': 'kQwQBXe7OSCq6HZ4cgloAA',
#   'alias': 'new-york-beer-project-orlando-winter-garden',
#   'name': 'New York Beer Project - Orlando',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/16KR30A79ZuX_VT_Wbr_cg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/new-york-beer-project-orlando-winter-garden?adjust_creative=0sqSARBZBNeJkSSMstb4jg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0sqSARBZBNeJkSSMstb4jg',
#   'review_count': 151,
#   'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 28.430321383265166,
#    'longitude': -81.61697878450263},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '9230 Miley Dr',
#    'address2': None,
#    'address3': '',
#    'city': 'Winter Garden',
#    'zip_code': '34787',
#    'country': 'US',
#    'state': 'FL',
#    'display_address': ['9230 Miley Dr', 'Winter Garden, FL 34787']},
#   'phone': '+14077988304',
#   'display_phone': '(407) 798-8304',
#   'distance': 8117.306717994822},
#  {'id': '3P0KIXTBwjFS9f-sBS3pPQ',
#   'alias': 'root-and-branch-bistro-and-bar-clermont',
#   'name': 'Root and Branch Bistro and Bar',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZhRBh13Vt4PG9gfD2rE09w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/root-and-branch-bistro-and-bar-clermont?adjust_creative=0sqSARBZBNeJkSSMstb4jg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0sqSARBZBNeJkSSMstb4jg',
#   'review_count': 279,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 28.5488546647162,
#    'longitude': -81.7277153581381},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1200 Oakley Seaver Dr',
#    'address2': 'Ste 102',
#    'address3': '',
#    'city': 'Clermont',
#    'zip_code': '34711',
#    'country': 'US',
#    'state': 'FL',
#    'display_address': ['1200 Oakley Seaver Dr',
#     'Ste 102',
#     'Clermont, FL 34711']},
#   'phone': '+13527084529',
#   'display_phone': '(352) 708-4529',
#   'distance': 18497.01209682257},
#  {'id': 'IEKgPTDM7Lf2Bv1vRo7hHQ',
#   'alias': 'saltgrass-steak-house-orlando-2',
#   'name': 'Saltgrass Steak House',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zej8P6XP6HVh63u_PTFXPA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/saltgrass-steak-house-orlando-2?adjust_creative=0sqSARBZBNeJkSSMstb4jg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0sqSARBZBNeJkSSMstb4jg',
#   'review_count': 223,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 28.44349931835887,
#    'longitude': -81.47096661291482},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '8440 International Dr',
#    'address2': '',
#    'address3': None,
#    'city': 'Orlando',
#    'zip_code': '32819',
#    'country': 'US',
#    'state': 'FL',
#    'display_address': ['8440 International Dr', 'Orlando, FL 32819']},
#   'phone': '+14073520314',
#   'display_phone': '(407) 352-0314',
#   'distance': 9194.724042166812},
#  {'id': 'eaNpTadVytk8WoOM0Et2dg',
#   'alias': 'the-boathouse-lake-buena-vista',
#   'name': 'The Boathouse',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KGdyTTh9ANpCtn7udTQpJA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-boathouse-lake-buena-vista?adjust_creative=0sqSARBZBNeJkSSMstb4jg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0sqSARBZBNeJkSSMstb4jg',
#   'review_count': 3154,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 28.37179431505456,
#    'longitude': -81.51800600391178},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '1620 E Buena Vista Dr',
#    'address2': '',
#    'address3': '',
#    'city': 'Lake Buena Vista',
#    'zip_code': '32830',
#    'country': 'US',
#    'state': 'FL',
#    'display_address': ['1620 E Buena Vista Dr', 'Lake Buena Vista, FL 32830']},
#   'phone': '+14079392628',
#   'display_phone': '(407) 939-2628',
#   'distance': 12530.61869402111},
#  {'id': '8lQbNdwVoj5q4Zh5wvOGNQ',
#   'alias': 'knife-and-spoon-orlando',
#   'name': 'Knife & Spoon',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cDG-9rCiqtTi-qWemPADtA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/knife-and-spoon-orlando?adjust_creative=0sqSARBZBNeJkSSMstb4jg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0sqSARBZBNeJkSSMstb4jg',
#   'review_count': 107,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'salad', 'title': 'Salad'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 28.4049382659328, 'longitude': -81.42942310849},
#   'transactions': ['delivery'],
#   'price': '$$$$',
#   'location': {'address1': '4012 Ctrl Florida Pkwy',
#    'address2': None,
#    'address3': None,
#    'city': 'Orlando',
#    'zip_code': '32837',
#    'country': 'US',
#    'state': 'FL',
#    'display_address': ['4012 Ctrl Florida Pkwy', 'Orlando, FL 32837']},
#   'phone': '+14073934333',
#   'display_phone': '(407) 393-4333',
#   'distance': 14867.614290608213},
#  {'id': 'hIpHPScNV5zQUJxhe6RjZQ',
#   'alias': 'longhorn-steakhouse-winter-garden-4',
#   'name': 'LongHorn Steakhouse',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/U8_rhDoI23qebCVnOiXSBA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/longhorn-steakhouse-winter-garden-4?adjust_creative=0sqSARBZBNeJkSSMstb4jg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0sqSARBZBNeJkSSMstb4jg',
#   'review_count': 145,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'bbq', 'title': 'Barbeque'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 28.524143, 'longitude': -81.5866},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '3118 Daniels Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Winter Garden',
#    'zip_code': '34787',
#    'country': 'US',
#    'state': 'FL',
#    'display_address': ['3118 Daniels Rd', 'Winter Garden, FL 34787']},
#   'phone': '+14076540272',
#   'display_phone': '(407) 654-0272',
#   'distance': 5812.040324279126},
#  {'id': 'ZQ5JAU0E6zM00pzbOSPuWQ',
#   'alias': 'da-silva-steak-house-no-title',
#   'name': 'Da silva steak house',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zYP7I3OkqZ8QMMJ5yzJ5Dg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/da-silva-steak-house-no-title?adjust_creative=0sqSARBZBNeJkSSMstb4jg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0sqSARBZBNeJkSSMstb4jg',
#   'review_count': 32,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 28.39444, 'longitude': -81.46385},
#   'transactions': [],
#   'location': {'address1': '11701 International Dr',
#    'address2': 'Ste 700',
#    'address3': '',
#    'city': 'Orlando',
#    'zip_code': '32821',
#    'country': 'US',
#    'state': 'FL',
#    'display_address': ['11701 International Dr',
#     'Ste 700',
#     'Orlando, FL 32821']},
#   'phone': '+14075657631',
#   'display_phone': '(407) 565-7631',
#   'distance': 13019.229728448632}]

# %%
## How many results total?
pd.DataFrame(results['businesses'])
# Out:
#                         id                                        alias  \
# 0   9rIAl_UPCS3ODRMdSyaPgA                        steak-on-fire-orlando
# 1   yS73rFfQFV2ggXQSlhv3Uw          matthews-steakhouse-winter-garden-2
# 2   wit_AlzCJqyq8IIytFxORg         the-wharf-at-sunset-walk-kissimmee-2
# 3   uV0N049zQmA_PUnbIK3oyg             eddie-vs-prime-seafood-orlando-2
# 4   aBdD__fQY23MKOIPmekrXw                          the-whiskey-orlando
# 5   _N8r_L8osRlusLJLfF3MPA        br77-brazilian-steakhouse-celebration
# 6   s2fM5fhc_QMow26UWugMog                      bull-and-bear-orlando-2
# 7   ZmC6t-RbvQ_HaNuZ3kighA       delmonicos-italian-steak-house-orlando
# 8   fwrYgOJCja_a6GozuPmOew                  boteco-do-manolo-windermere
# 9   Vlwa2HgckFlUmAqTN1HEfQ              teak-neighborhood-grill-orlando
# 10  3E67cNRXVCfWu07GUzNqAg                          ocean-prime-orlando
# 11  yo0SkNe0fEAPObuRdAK4yg                         la-boucherie-orlando
# 12  P54EpC04TcfKcr-bYF12lA             black-rock-bar-and-grill-orlando
# 13  kQwQBXe7OSCq6HZ4cgloAA  new-york-beer-project-orlando-winter-garden
# 14  3P0KIXTBwjFS9f-sBS3pPQ      root-and-branch-bistro-and-bar-clermont
# 15  IEKgPTDM7Lf2Bv1vRo7hHQ              saltgrass-steak-house-orlando-2
# 16  eaNpTadVytk8WoOM0Et2dg               the-boathouse-lake-buena-vista
# 17  8lQbNdwVoj5q4Zh5wvOGNQ                      knife-and-spoon-orlando
# 18  hIpHPScNV5zQUJxhe6RjZQ          longhorn-steakhouse-winter-garden-4
# 19  ZQ5JAU0E6zM00pzbOSPuWQ                da-silva-steak-house-no-title
#
#                                name  \
# 0                     Steak on Fire
# 1              Matthew's Steakhouse
# 2          The Wharf at Sunset Walk
# 3           Eddie V's Prime Seafood
# 4                       The Whiskey
# 5         BR77 Brazilian Steakhouse
# 6                     Bull and Bear
# 7   Delmonico's Italian Steak House
# 8                  Boteco do Manolo
# 9           Teak Neighborhood Grill
# 10                      Ocean Prime
# 11                     La Boucherie
# 12           Black Rock Bar & Grill
# 13  New York Beer Project - Orlando
# 14   Root and Branch Bistro and Bar
# 15            Saltgrass Steak House
# 16                    The Boathouse
# 17                    Knife & Spoon
# 18              LongHorn Steakhouse
# 19             Da silva steak house
#
#                                             image_url  is_closed  \
# 0   https://s3-media3.fl.yelpcdn.com/bphoto/vzahwT...      False
# 1   https://s3-media3.fl.yelpcdn.com/bphoto/jkRiGG...      False
# 2   https://s3-media2.fl.yelpcdn.com/bphoto/6i1p7c...      False
# 3   https://s3-media4.fl.yelpcdn.com/bphoto/8F2qYH...      False
# 4   https://s3-media3.fl.yelpcdn.com/bphoto/gCMLA8...      False
# 5   https://s3-media4.fl.yelpcdn.com/bphoto/rLcGIO...      False
# 6   https://s3-media4.fl.yelpcdn.com/bphoto/WKgtcV...      False
# 7   https://s3-media3.fl.yelpcdn.com/bphoto/-EKhF9...      False
# 8   https://s3-media2.fl.yelpcdn.com/bphoto/Zg6yQv...      False
# 9   https://s3-media4.fl.yelpcdn.com/bphoto/HRjCIw...      False
# 10  https://s3-media3.fl.yelpcdn.com/bphoto/xxrdKN...      False
# 11  https://s3-media4.fl.yelpcdn.com/bphoto/6cR95X...      False
# 12  https://s3-media1.fl.yelpcdn.com/bphoto/t1YuW-...      False
# 13  https://s3-media1.fl.yelpcdn.com/bphoto/16KR30...      False
# 14  https://s3-media2.fl.yelpcdn.com/bphoto/ZhRBh1...      False
# 15  https://s3-media2.fl.yelpcdn.com/bphoto/zej8P6...      False
# 16  https://s3-media3.fl.yelpcdn.com/bphoto/KGdyTT...      False
# 17  https://s3-media2.fl.yelpcdn.com/bphoto/cDG-9r...      False
# 18  https://s3-media3.fl.yelpcdn.com/bphoto/U8_rhD...      False
# 19  https://s3-media3.fl.yelpcdn.com/bphoto/zYP7I3...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/steak-on-fire-orlando...           358
# 1   https://www.yelp.com/biz/matthews-steakhouse-w...           133
# 2   https://www.yelp.com/biz/the-wharf-at-sunset-w...           418
# 3   https://www.yelp.com/biz/eddie-vs-prime-seafoo...          1048
# 4   https://www.yelp.com/biz/the-whiskey-orlando?a...           849
# 5   https://www.yelp.com/biz/br77-brazilian-steakh...            48
# 6   https://www.yelp.com/biz/bull-and-bear-orlando...           446
# 7   https://www.yelp.com/biz/delmonicos-italian-st...          1239
# 8   https://www.yelp.com/biz/boteco-do-manolo-wind...             5
# 9   https://www.yelp.com/biz/teak-neighborhood-gri...           969
# 10  https://www.yelp.com/biz/ocean-prime-orlando?a...           676
# 11  https://www.yelp.com/biz/la-boucherie-orlando?...           408
# 12  https://www.yelp.com/biz/black-rock-bar-and-gr...           473
# 13  https://www.yelp.com/biz/new-york-beer-project...           151
# 14  https://www.yelp.com/biz/root-and-branch-bistr...           279
# 15  https://www.yelp.com/biz/saltgrass-steak-house...           223
# 16  https://www.yelp.com/biz/the-boathouse-lake-bu...          3154
# 17  https://www.yelp.com/biz/knife-and-spoon-orlan...           107
# 18  https://www.yelp.com/biz/longhorn-steakhouse-w...           145
# 19  https://www.yelp.com/biz/da-silva-steak-house-...            32
#
#                                            categories  rating  \
# 0   [{'alias': 'steak', 'title': 'Steakhouses'}, {...     4.5
# 1        [{'alias': 'steak', 'title': 'Steakhouses'}]     4.0
# 2   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.5
# 3   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.5
# 4   [{'alias': 'tradamerican', 'title': 'American ...     4.5
# 5   [{'alias': 'steak', 'title': 'Steakhouses'}, {...     4.0
# 6   [{'alias': 'steak', 'title': 'Steakhouses'}, {...     4.5
# 7   [{'alias': 'steak', 'title': 'Steakhouses'}, {...     4.0
# 8   [{'alias': 'brazilian', 'title': 'Brazilian'},...     4.5
# 9   [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.0
# 10  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.5
# 11  [{'alias': 'french', 'title': 'French'}, {'ali...     4.5
# 12  [{'alias': 'newamerican', 'title': 'American (...     3.5
# 13   [{'alias': 'gastropubs', 'title': 'Gastropubs'}]     4.5
# 14  [{'alias': 'newamerican', 'title': 'American (...     4.5
# 15  [{'alias': 'steak', 'title': 'Steakhouses'}, {...     3.5
# 16  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.5
# 17  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 18  [{'alias': 'steak', 'title': 'Steakhouses'}, {...     3.0
# 19       [{'alias': 'steak', 'title': 'Steakhouses'}]     4.5
#
#                                           coordinates        transactions  \
# 0   {'latitude': 28.4506829, 'longitude': -81.485305}  [pickup, delivery]
# 1   {'latitude': 28.5645698339131, 'longitude': -8...          [delivery]
# 2   {'latitude': 28.343873101245265, 'longitude': ...  [pickup, delivery]
# 3      {'latitude': 28.44976, 'longitude': -81.48521}          [delivery]
# 4    {'latitude': 28.450702, 'longitude': -81.486127}          [delivery]
# 5   {'latitude': 28.344453143028165, 'longitude': ...                  []
# 6    {'latitude': 28.352868, 'longitude': -81.533747}                  []
# 7    {'latitude': 28.420272, 'longitude': -81.460726}          [delivery]
# 8   {'latitude': 28.44898180468064, 'longitude': -...                  []
# 9      {'latitude': 28.50895, 'longitude': -81.47101}          [delivery]
# 10  {'latitude': 28.45077631932273, 'longitude': -...                  []
# 11  {'latitude': 28.454501838355, 'longitude': -81...          [delivery]
# 12   {'latitude': 28.494411, 'longitude': -81.507644}  [pickup, delivery]
# 13  {'latitude': 28.430321383265166, 'longitude': ...                  []
# 14  {'latitude': 28.5488546647162, 'longitude': -8...                  []
# 15  {'latitude': 28.44349931835887, 'longitude': -...  [pickup, delivery]
# 16  {'latitude': 28.37179431505456, 'longitude': -...          [delivery]
# 17  {'latitude': 28.4049382659328, 'longitude': -8...          [delivery]
# 18     {'latitude': 28.524143, 'longitude': -81.5866}                  []
# 19     {'latitude': 28.39444, 'longitude': -81.46385}                  []
#
#    price                                           location         phone  \
# 0     $$  {'address1': '7541 Sand Lake Rd', 'address2': ...  +14074402323
# 1    $$$  {'address1': '360 W Plant St', 'address2': '',...  +14075207511
# 2     $$  {'address1': '3274 Margaritaville Blvd', 'addr...  +14079547290
# 3    $$$  {'address1': '7488 W Sand Lake Rd', 'address2'...  +14073553011
# 4     $$  {'address1': '7563 W Sand Lake Rd', 'address2'...  +14079306517
# 5    NaN  {'address1': '3228 Margaritaville Blvd', 'addr...  +13219004377
# 6   $$$$  {'address1': '14200 Bonnet Creek Resort Ln', '...  +14075975500
# 7     $$  {'address1': '6115 Westwood Blvd', 'address2':...  +14072262662
# 8    NaN  {'address1': '11620 Lakeside Village Ln', 'add...  +14076148310
# 9     $$  {'address1': '6400 Times Sq Ave', 'address2': ...  +14073135111
# 10   $$$  {'address1': '7339 W Sand Lake Rd 400', 'addre...  +14077814880
# 11    $$  {'address1': '7625 Turkey Lake Rd', 'address2'...  +14079301708
# 12    $$  {'address1': '8965 Conroy Windermere Rd', 'add...  +14075055195
# 13    $$  {'address1': '9230 Miley Dr', 'address2': None...  +14077988304
# 14    $$  {'address1': '1200 Oakley Seaver Dr', 'address...  +13527084529
# 15    $$  {'address1': '8440 International Dr', 'address...  +14073520314
# 16   $$$  {'address1': '1620 E Buena Vista Dr', 'address...  +14079392628
# 17  $$$$  {'address1': '4012 Ctrl Florida Pkwy', 'addres...  +14073934333
# 18    $$  {'address1': '3118 Daniels Rd', 'address2': ''...  +14076540272
# 19   NaN  {'address1': '11701 International Dr', 'addres...  +14075657631
#
#      display_phone      distance
# 0   (407) 440-2323   7585.656804
# 1   (407) 520-7511  10044.057790
# 2   (407) 954-7290  15769.757232
# 3   (407) 355-3011   7794.688480
# 4   (407) 930-6517   7512.004788
# 5   (321) 900-4377  15901.047756
# 6   (407) 597-5500  14244.446547
# 7   (407) 226-2662  11379.523523
# 8   (407) 614-8310   3456.146666
# 9   (407) 313-5111   8921.531236
# 10  (407) 781-4880   8025.000111
# 11  (407) 930-1708   8334.427606
# 12  (407) 505-5195   4973.925875
# 13  (407) 798-8304   8117.306718
# 14  (352) 708-4529  18497.012097
# 15  (407) 352-0314   9194.724042
# 16  (407) 939-2628  12530.618694
# 17  (407) 393-4333  14867.614291
# 18  (407) 654-0272   5812.040324
# 19  (407) 565-7631  13019.229728

# %% [markdown]
# - Where is the actual data we want to save?

# %%
## How many did we get the details for?
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %% [markdown]
# - Calculate how many pages of results needed to cover the total_results

# %%
# Use math.ceil to round up for the total number of pages of results.
n_pages = math.ceil((results['total'])/ results_per_page)
n_pages
# Out:
# 95

# %%
for i in tqdm_notebook(range(1,n_pages+1)):
    ## The block of code we want to TRY to run
    try:
        
        time.sleep(.2)
        
        ## Read in results in progress file and check the length
        with open(JSON_FILE, 'r') as f:
            previous_results = json.load(f)
        
        ## save number of results for to use as offset
        n_results = len(previous_results)
        
        
        ## use n_results as the OFFSET 
        results = Yelp.search_query(location = location, term = term,
                                   offset = n_results+1)

        ## append new results and save to file
        previous_results.extend(results['businesses'])
        
        with open(JSON_FILE, 'w') as f:
            json.dump(previous_results, f)

            
    ## What to do if we get an error/exception.
    except Exception as e:
        print(' [!] ERROR', e)
# Out:
#   0%|          | 0/95 [00:00<?, ?it/s]
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
#  [!] ERROR VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.

# %% [markdown]
# ## Open the Final JSON File with Pandas

# %%
df = pd.read_json(JSON_FILE)

# %%
## convert the filename to a .csv.gz
csv_file = JSON_FILE.replace('.json','.csv.gz')
csv_file
# Out:
# 'Data/Orlando-steak.csv.gz'

# %%
## Save it as a compressed csv (to save space)
df.to_csv(csv_file, compression = 'gzip', index = False)

# %% [markdown]
# ## Bonus: compare filesize with os module's `os.path.getsize`

# %%
size_json = os.path.getsize(JSON_FILE)
size_csv_gz = os.path.getsize(JSON_FILE.replace('.json','.csv.gz'))

print(f'JSON FILE: {size_json:,} Bytes')
print(f'CSV.GZ FILE: {size_csv_gz:,} Bytes')

print(f'the csv.gz is {size_json/size_csv_gz} times smaller!')
# Out:
# JSON FILE: 2 Bytes
# CSV.GZ FILE: 46 Bytes
# the csv.gz is 0.043478260869565216 times smaller!
